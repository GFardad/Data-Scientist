# %%
import numpy as np
import time
import torch

# %%
array_1m1 = torch.rand(1000000)
array_1m2 = torch.rand(1000000)
array_result = []
t0 = time.time()
for a, (i, j) in enumerate(zip(array_1m1, array_1m2)):
    array_result.append(i * j)
t1 = time.time()
timea = t1 - t0

t0 = time.time()
array_1m1.dot(array_1m2)
print(
    f" time a : {timea} \n time b : {time.time() - t0 }\n numpy is : {timea/(time.time() - t0)} times faster"
)
# Out:
#  time a : 3.614863157272339
#  time b : 0.0018727779388427734
#  numpy is : 1928.25066768409 times faster

# %%
x = [2]
w = [0.5]
b = 0.0
y_t = 1
result = []
y_p = np.dot(w,x) + 1
L = y_p - y_t
# Out:
# -1.0
