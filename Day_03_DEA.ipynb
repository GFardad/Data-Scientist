# %%
import pandas as pd
import numpy as np

df_eda = pd.read_csv("cleaned_data.csv")

print(df_eda)
print("\n","-"*10,"\n")
product_summary = df_eda.groupby("Product")["Price"].agg(["mean", "sum"])
print(product_summary)
tops = product_summary.sort_values(by="mean",ascending=False,inplace=False)
print(tops)
# Out:
#    TransactionID   Product    Price  Quantity
# 0            101    Laptop  1200.00       1.0
# 1            102   Monitor   300.00       2.0
# 2            103     Mouse    50.00       1.0
# 3            105  Keyboard   398.75       1.0
#
#  ----------
#
#              mean      sum
# Product
# Keyboard   398.75   398.75
# Laptop    1200.00  1200.00
# Monitor    300.00   300.00
# Mouse       50.00    50.00
#              mean      sum
# Product
# Laptop    1200.00  1200.00
# Keyboard   398.75   398.75
# Monitor    300.00   300.00
# Mouse       50.00    50.00
